# %%
import numpy as np
fitness_data = np.array([[5000, 200, 6]##>>25
                         ,[7000, 250, 7],##>> 28
                         [6500, 230, 6],##>28.26
                         [8000, 300, 8],##>>26.333
                         [9000, 320, 7],##>>28.125
                         [7500, 270, 6],##>>27.7778
                         [12000, 400, 5]]) ##>>30
# Out:
# 6.428571428571429

# %%
## dimension
fitness_data.ndim
# Out:
# 2

# %%
## shape
fitness_data.shape
# Out:
# (7, 3)

# %%
#number of elements
fitness_data.size
# Out:
# 21

# %%
## all step values
fitness_data[:,0]
# Out:
# array([ 5000,  7000,  6500,  8000,  9000,  7500, 12000])

# %%
### all calories values
fitness_data[:,1]
# Out:
# array([200, 250, 230, 300, 320, 270, 400])

# %%
## all hours values
fitness_data[:,2]
# Out:
# array([6, 7, 6, 8, 7, 6, 5])

# %%
## first 3 days
fitness_data[:3,:]
# Out:
# array([[5000,  200,    6],
#        [7000,  250,    7],
#        [6500,  230,    6]])

# %%
## step&&calories
fitness_data[:,0:2]
# Out:
# array([[ 5000,   200],
#        [ 7000,   250],
#        [ 6500,   230],
#        [ 8000,   300],
#        [ 9000,   320],
#        [ 7500,   270],
#        [12000,   400]])

# %%
## reshape step column
fitness_data[:,0].reshape(7,1)
# Out:
# array([[ 5000],
#        [ 7000],
#        [ 6500],
#        [ 8000],
#        [ 9000],
#        [ 7500],
#        [12000]])

# %%
### reshape all data
fitness_data[:,:].reshape(3,7)
# Out:
# array([[ 5000,   200,     6,  7000,   250,     7,  6500],
#        [  230,     6,  8000,   300,     8,  9000,   320],
#        [    7,  7500,   270,     6, 12000,   400,     5]])

# %%
fitness_data[fitness_data[:,0]>8000]
# Out:
# array([[ 9000,   320,     7],
#        [12000,   400,     5]])

# %%
fitness_data[fitness_data[:,2]<6]
# Out:
# array([[12000,   400,     5]])

# %%
fitness_data[fitness_data[:,1]>300]
# Out:
# array([[ 9000,   320,     7],
#        [12000,   400,     5]])

# %%
fitness_data[:,0].mean()
# Out:
# 7857.142857142857

# %%
fitness_data[:,0].max()
# Out:
# 12000

# %%
fitness_data[:,2].min()
# Out:
# 5

# %%
fitness_data[:,1].std()
# Out:
# 61.278887398649196

# %%
fitness_data[:,0].max()-fitness_data[:,0].min()
# Out:
# 7000
